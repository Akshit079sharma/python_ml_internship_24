# %% [markdown]
# # Pandas
# **clean,Import,Export**
#
# *series*#1d array
#
# *Data frame*2d array

# %%
import numpy as np
import pandas as pd
dic={
    "Name":["Ram","dhruv","shyam","kunal","kajal","roni"],
    "Roll no":[1,2,3,4,5,6],
    "Grades":["A","B","C","c","D","A"],
    "Email":["abc@xyz","def@xyz","hig@xyz","jkl@xyz","ghi@xyz","hii@xyz"]
}
print(dic)
df = pd.DataFrame(dic)
print(df)
# Out:
# {'Name': ['Ram', 'dhruv', 'shyam', 'kunal', 'kajal', 'roni'], 'Roll no': [1, 2, 3, 4, 5, 6], 'Grades': ['A', 'B', 'C', 'c', 'D', 'A'], 'Email': ['abc@xyz', 'def@xyz', 'hig@xyz', 'jkl@xyz', 'ghi@xyz', 'hii@xyz']}
#     Name  Roll no Grades    Email
# 0    Ram        1      A  abc@xyz
# 1  dhruv        2      B  def@xyz
# 2  shyam        3      C  hig@xyz
# 3  kunal        4      c  jkl@xyz
# 4  kajal        5      D  ghi@xyz
# 5   roni        6      A  hii@xyz

# %%
df .head()
# Out:
#     Name  Roll no Grades    Email
# 0    Ram        1      A  abc@xyz
# 1  dhruv        2      B  def@xyz
# 2  shyam        3      C  hig@xyz
# 3  kunal        4      c  jkl@xyz
# 4  kajal        5      D  ghi@xyz

# %%
df.tail()
# Out:
#     Name  Roll no Grades    Email
# 1  dhruv        2      B  def@xyz
# 2  shyam        3      C  hig@xyz
# 3  kunal        4      c  jkl@xyz
# 4  kajal        5      D  ghi@xyz
# 5   roni        6      A  hii@xyz

# %%
df.head(2)
# Out:
#     Name  Roll no Grades    Email
# 0    Ram        1      A  abc@xyz
# 1  dhruv        2      B  def@xyz

# %%
df.tail(2)
# Out:
#     Name  Roll no Grades    Email
# 4  kajal        5      D  ghi@xyz
# 5   roni        6      A  hii@xyz

# %%
df.describe()
# Out:
#         Roll no
# count  6.000000
# mean   3.500000
# std    1.870829
# min    1.000000
# 25%    2.250000
# 50%    3.500000
# 75%    4.750000
# max    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     6 non-null      object
#  1   Roll no  6 non-null      int64
#  2   Grades   6 non-null      object
#  3   Email    6 non-null      object
# dtypes: int64(1), object(3)
# memory usage: 324.0+ bytes

# %%
df.shape
# Out:
# (6, 4)

# %%
cus = pd.read_csv('customer.csv')
cus
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
type(cus)
# Out:
# pandas.core.frame.DataFrame

# %%
type(cus['CustomerID'])
# Out:
# pandas.core.series.Series

# %%
cus.index
# Out:
# RangeIndex(start=0, stop=91, step=1)

# %%
cus.columns
# Out:
# Index(['CustomerID', 'Company Name', 'Costumer Name', 'City', 'PostalCode',
#        'Country'],
#       dtype='object')

# %%
cus.to_numpy()
# Out:
# array([[1, 'Alfreds Futterkiste', 'Maria Anders', 'Berlin', 12209,
#         'Germany'],
#        [2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo',
#         'Mexico D.F.', 5021, 'Mexico'],
#        [3, 'Antonio Moreno Taqueria', 'Antonio Moreno', 'Mexico D.F.',
#         5023, 'Mexico'],
#        [4, 'Around the Horn', 'Thomas Hardy', 'London', 34626, 'UK'],
#        [5, 'Berglunds snabbkp', 'Christina Berglund', 'Lulea', 95822,
#         'Sweden'],
#        [6, 'Blauer See Delikatessen', 'Hanna Moos', 'Mannheim', 68306,
#         'Germany'],
#        [7, 'Blondel pere et fils', 'Frederique Citeaux', 'Strasbourg',
#         67000, 'France'],
#        [8, 'BOlido Comidas preparadas', 'Martin Sommer', 'Madrid', 28023,
#         'Spain'],
#        [9, 'Bon app', 'Laurence Lebihans', 'Marseille', 13008, 'France'],
#        [10, 'Bottom-Dollar Marketse', 'Elizabeth Lincoln', 'Tsawassen',
#         254685, 'Canada'],
# ...

# %%
cus.T
# Out:
#                                 0                                   1   \
# CustomerID                       1                                   2
# Company Name   Alfreds Futterkiste  Ana Trujillo Emparedados y helados
# Costumer Name         Maria Anders                        Ana Trujillo
# City                        Berlin                         Mexico D.F.
# PostalCode                   12209                                5021
# Country                    Germany                              Mexico
#
#                                     2                3                   4   \
# CustomerID                           3                4                   5
# Company Name   Antonio Moreno Taqueria  Around the Horn   Berglunds snabbkp
# Costumer Name           Antonio Moreno     Thomas Hardy  Christina Berglund
# City                       Mexico D.F.           London               Lulea
# PostalCode                        5023            34626               95822
# ...

# %%
cus.drop(0)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 3            4                     Around the Horn        Thomas Hardy
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 1   Mexico D.F.        5021   Mexico
# 2   Mexico D.F.        5023   Mexico
# ...

# %%
cus.drop(3)
# Out:
#     CustomerID                        Company Name       Costumer Name  \
# 0            1                 Alfreds Futterkiste        Maria Anders
# 1            2  Ana Trujillo Emparedados y helados        Ana Trujillo
# 2            3             Antonio Moreno Taqueria      Antonio Moreno
# 4            5                   Berglunds snabbkp  Christina Berglund
# 5            6             Blauer See Delikatessen          Hanna Moos
# ..         ...                                 ...                 ...
# 86          87                      Wartian Herkku    Pirkko Koskitalo
# 87          88              Wellington Importadora       Paula Parente
# 88          89                White Clover Markets      Karl Jablonski
# 89          90                         Wilman Kala     Matti Karttunen
# 90          91                              Wolski             Zbyszek
#
#            City  PostalCode  Country
# 0        Berlin       12209  Germany
# 1   Mexico D.F.        5021   Mexico
# ...

# %%
cus.drop('Company Name',axis=1)
# Out:
#     CustomerID       Costumer Name         City  PostalCode  Country
# 0            1        Maria Anders       Berlin       12209  Germany
# 1            2        Ana Trujillo  Mexico D.F.        5021   Mexico
# 2            3      Antonio Moreno  Mexico D.F.        5023   Mexico
# 3            4        Thomas Hardy       London       34626       UK
# 4            5  Christina Berglund        Lulea       95822   Sweden
# ..         ...                 ...          ...         ...      ...
# 86          87    Pirkko Koskitalo         Oulu       90110  Finland
# 87          88       Paula Parente      Resende       51849   Brazil
# 88          89      Karl Jablonski      Seattle       98128      USA
# 89          90     Matti Karttunen     Helsinki       21240  Finland
# 90          91             Zbyszek        Walla       56189   Poland
#
# [91 rows x 5 columns]

# %%
cus = pd.read_csv('customer.csv')
cus.loc[(48,78),('Company Name','Costumer Name')]
# Out:
#                     Company Name     Costumer Name
# 48  Magazzini Alimentari Riuniti  Giovanni Rovelli
# 78            Toms Spezialitaten     Karin Josephs

# %%
cus.loc[np.arange(48,78),('Company Name','Costumer Name')]
# Out:
#                     Company Name        Costumer Name
# 48  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49                  Maison Dewey      Catherine Dewey
# 50                Mere Paillarde       Jean Fresniere
# 51        Morgenstern Gesundkost      Alexander Feuer
# 52                   North/South       Simon Crowther
# 53        Oceano Atlantico Ltda.       Yvonne Moncada
# 54        Old World Delicatessen        Rene Phillips
# 55            Ottilies Kaseladen  Henriette Pfalzheim
# 56             Paris specialites       Marie Bertrand
# 57     Pericles Comidas clasicas  Guillermo Fernandez
# 58              Piccolo und mehr          Georg Pipps
# 59       Princesa Isabel Vinhoss     Isabel de Castro
# 60                   Que Delicia     Bernardo Batista
# 61                 Queen Cozinha       Lucia Carvalho
# 62                    QUICK-Stop          Horst Kloss
# 63                 Rancho grande     Sergio Gutierrez
# ...

# %%
cus.loc[np.arange(48,78),:]
# Out:
#     CustomerID                  Company Name        Costumer Name  \
# 48          49  Magazzini Alimentari Riuniti     Giovanni Rovelli
# 49          50                  Maison Dewey      Catherine Dewey
# 50          51                Mere Paillarde       Jean Fresniere
# 51          52        Morgenstern Gesundkost      Alexander Feuer
# 52          53                   North/South       Simon Crowther
# 53          54        Oceano Atlantico Ltda.       Yvonne Moncada
# 54          55        Old World Delicatessen        Rene Phillips
# 55          56            Ottilies Kaseladen  Henriette Pfalzheim
# 56          57             Paris specialites       Marie Bertrand
# 57          58     Pericles Comidas clasicas  Guillermo Fernandez
# 58          59              Piccolo und mehr          Georg Pipps
# 59          60       Princesa Isabel Vinhoss     Isabel de Castro
# 60          61                   Que Delicia     Bernardo Batista
# ...

# %%
cus.loc[:,'Company Name']
# Out:
# 0                    Alfreds Futterkiste
# 1     Ana Trujillo Emparedados y helados
# 2                Antonio Moreno Taqueria
# 3                        Around the Horn
# 4                      Berglunds snabbkp
#                      ...
# 86                        Wartian Herkku
# 87                Wellington Importadora
# 88                  White Clover Markets
# 89                           Wilman Kala
# 90                                Wolski
# Name: Company Name, Length: 91, dtype: object

# %%
np.array(cus.loc[np.arange(48,78),:])
# Out:
# array([[49, 'Magazzini Alimentari Riuniti', 'Giovanni Rovelli',
#         'Bergamo', 24100, 'Italy'],
#        [50, 'Maison Dewey', 'Catherine Dewey', 'Bruxelles', 21365,
#         'Belgium'],
#        [51, 'Mere Paillarde', 'Jean Fresniere', 'Montreal', 69162,
#         'Canada'],
#        [52, 'Morgenstern Gesundkost', 'Alexander Feuer', 'Leipzig', 4179,
#         'Germany'],
#        [53, 'North/South', 'Simon Crowther', 'London', 196215, 'UK'],
#        [54, 'Oceano Atlantico Ltda.', 'Yvonne Moncada', 'Buenos Aires',
#         1010, 'Argentina'],
#        [55, 'Old World Delicatessen', 'Rene Phillips', 'Anchorage',
#         99508, 'USA'],
#        [56, 'Ottilies Kaseladen', 'Henriette Pfalzheim', 'Koln', 50739,
#         'Germany'],
#        [57, 'Paris specialites', 'Marie Bertrand', 'Paris', 75012,
#         'France'],
#        [58, 'Pericles Comidas clasicas', 'Guillermo Fernandez',
#         'Mexico D.F.', 5033, 'Mexico'],
# ...

# %%
company_data={
    1: {'Company Name': 'TechCorp', 'Employee Name': 'Alice Smith', 'Position': 'Software Engineer'},
    2: {'Company Name': 'HealthPlus', 'Employee Name': 'Bob Johnson', 'Position': 'Data Scientist'},
    3: {'Company Name': 'EduWorld', 'Employee Name': 'Charlie Brown', 'Position': 'Teacher'},
    4: {'Company Name': 'FinTrust', 'Employee Name': 'Dana White', 'Position': 'Financial Analyst'},
    5: {'Company Name': 'AutoMax', 'Employee Name': 'Eve Davis', 'Position': 'Mechanical Engineer'},
    6: {'Company Name': 'BioLife', 'Employee Name': 'Frank Wilson', 'Position': 'Biologist'},
    7: {'Company Name': 'WebSolutions', 'Employee Name': 'Grace Lee', 'Position': 'Web Developer'},
    8: {'Company Name': 'MediCare', 'Employee Name': 'Henry King', 'Position': 'Nurse'},
    9: {'Company Name': 'GreenEnergy', 'Employee Name': 'Ivy Lewis', 'Position': 'Environmental Scientist'},
    10: {'Company Name': 'RetailCo', 'Employee Name': 'Jack Walker', 'Position': 'Store Manager'},
    11: {'Company Name': 'Foodies', 'Employee Name': 'Karen Hall', 'Position': 'Chef'},
    12: {'Company Name': 'SafeHome', 'Employee Name': 'Liam Young', 'Position': 'Security Specialist'},
    13: {'Company Name': 'DesignHub', 'Employee Name': 'Mona Scott', 'Position': 'Graphic Designer'},
    14: {'Company Name': 'LogiTech', 'Employee Name': 'Nathan Adams', 'Position': 'Logistics Manager'},
    15: {'Company Name': 'TravelEase', 'Employee Name': 'Olivia Mitchell', 'Position': 'Travel Consultant'},
    16: {'Company Name': 'PharmaCare', 'Employee Name': 'Peter Baker', 'Position': 'Pharmacist'},
    17: {'Company Name': 'BuildIt', 'Employee Name': 'Quincy Harris', 'Position': 'Civil Engineer'},
    18: {'Company Name': 'TechNova', 'Employee Name': 'Rachel Turner', 'Position': 'Product Manager'},
    19: {'Company Name': 'FinServe', 'Employee Name': 'Steve Roberts', 'Position': 'Accountant'},
    20: {'Company Name': 'AgriPro', 'Employee Name': 'Tina Lewis', 'Position': 'Agricultural Scientist'},
    21: {'Company Name': 'Fashionista', 'Employee Name': 'Ursula Clark', 'Position': 'Fashion Designer'},
    22: {'Company Name': 'CleanTech', 'Employee Name': 'Victor Rodriguez', 'Position': 'Chemical Engineer'},
    23: {'Company Name': 'EventMasters', 'Employee Name': 'Wendy Martinez', 'Position': 'Event Planner'},
    24: {'Company Name': 'MediaWave', 'Employee Name': 'Xander Harris', 'Position': 'Media Analyst'},
    25: {'Company Name': 'SafeDrive', 'Employee Name': 'Yvonne Perez', 'Position': 'Driving Instructor'},
    26: {'Company Name': 'SmartHome', 'Employee Name': 'Zachary Edwards', 'Position': 'Home Automation Specialist'},
    27: {'Company Name': 'PetCare', 'Employee Name': 'Amber Murphy', 'Position': 'Veterinarian'},
    28: {'Company Name': 'BookWorm', 'Employee Name': 'Brandon Collins', 'Position': 'Librarian'},
    29: {'Company Name': 'TechFusion', 'Employee Name': 'Cathy Howard', 'Position': 'UI/UX Designer'},
    30: {'Company Name': 'Sportify', 'Employee Name': 'David Scott', 'Position': 'Fitness Trainer'},
    31: {'Company Name': 'CleanAir', 'Employee Name': 'Emily Ward', 'Position': 'Environmental Consultant'},
    32: {'Company Name': 'AquaPure', 'Employee Name': 'Felix Turner', 'Position': 'Hydrologist'},
    33: {'Company Name': 'Solaris', 'Employee Name': 'Gina Martin', 'Position': 'Solar Energy Technician'},
    34: {'Company Name': 'UrbanPlan', 'Employee Name': 'Harold Moore', 'Position': 'Urban Planner'},
    35: {'Company Name': 'E-Comm', 'Employee Name': 'Isabella Clark', 'Position': 'E-commerce Manager'},
    36: {'Company Name': 'AdWise', 'Employee Name': 'Jason Phillips', 'Position': 'Marketing Specialist'},
    37: {'Company Name': 'BuildTech', 'Employee Name': 'Kelly Harris', 'Position': 'Construction Manager'},
    38: {'Company Name': 'TechSolutions', 'Employee Name': 'Lance Lewis', 'Position': 'IT Support Specialist'},
    39: {'Company Name': 'EduMentor', 'Employee Name': 'Megan Walker', 'Position': 'Education Consultant'},
    40: {'Company Name': 'FarmFresh', 'Employee Name': 'Noah Johnson', 'Position': 'Farm Manager'},
    41: {'Company Name': 'SkyHigh', 'Employee Name': 'Olivia Davis', 'Position': 'Pilot'},
    42: {'Company Name': 'SecureNet', 'Employee Name': 'Paul Anderson', 'Position': 'Network Security Engineer'},
    43: {'Company Name': 'TechSpace', 'Employee Name': 'Quinn Lee', 'Position': 'Data Analyst'},
    44: {'Company Name': 'BioPharma', 'Employee Name': 'Rita Adams', 'Position': 'Research Scientist'},
    45: {'Company Name': 'EcoWorld', 'Employee Name': 'Sam Harris', 'Position': 'Conservationist'},
    46: {'Company Name': 'Artistry', 'Employee Name': 'Tina Thompson', 'Position': 'Artist'},
    47: {'Company Name': 'MedEquip', 'Employee Name': 'Uma Williams', 'Position': 'Biomedical Engineer'},
    48: {'Company Name': 'GreenThumb', 'Employee Name': 'Victor Brown', 'Position': 'Horticulturist'},
    49: {'Company Name': 'RoboTech', 'Employee Name': 'Wesley King', 'Position': 'Robotics Engineer'},
    50: {'Company Name': 'BlueSky', 'Employee Name': 'Xenia White', 'Position': 'Aerospace Engineer'}
}

# Display the dictionary
print(company_data)
# Out:
# {1: {'Company Name': 'TechCorp', 'Employee Name': 'Alice Smith', 'Position': 'Software Engineer'}, 2: {'Company Name': 'HealthPlus', 'Employee Name': 'Bob Johnson', 'Position': 'Data Scientist'}, 3: {'Company Name': 'EduWorld', 'Employee Name': 'Charlie Brown', 'Position': 'Teacher'}, 4: {'Company Name': 'FinTrust', 'Employee Name': 'Dana White', 'Position': 'Financial Analyst'}, 5: {'Company Name': 'AutoMax', 'Employee Name': 'Eve Davis', 'Position': 'Mechanical Engineer'}, 6: {'Company Name': 'BioLife', 'Employee Name': 'Frank Wilson', 'Position': 'Biologist'}, 7: {'Company Name': 'WebSolutions', 'Employee Name': 'Grace Lee', 'Position': 'Web Developer'}, 8: {'Company Name': 'MediCare', 'Employee Name': 'Henry King', 'Position': 'Nurse'}, 9: {'Company Name': 'GreenEnergy', 'Employee Name': 'Ivy Lewis', 'Position': 'Environmental Scientist'}, 10: {'Company Name': 'RetailCo', 'Employee Name': 'Jack Walker', 'Position': 'Store Manager'}, 11: {'Company Name': 'Foodies', 'Employee Name'
# ...

# %%
cd=pd.DataFrame(company_data)

cd
# Out:
#                               1               2              3   \
# Company Name            TechCorp      HealthPlus       EduWorld
# Employee Name        Alice Smith     Bob Johnson  Charlie Brown
# Position       Software Engineer  Data Scientist        Teacher
#
#                               4                    5             6   \
# Company Name            FinTrust              AutoMax       BioLife
# Employee Name         Dana White            Eve Davis  Frank Wilson
# Position       Financial Analyst  Mechanical Engineer     Biologist
#
#                           7           8                        9   \
# Company Name    WebSolutions    MediCare              GreenEnergy
# Employee Name      Grace Lee  Henry King                Ivy Lewis
# Position       Web Developer       Nurse  Environmental Scientist
#
#                           10  ...            41                         42  \
# Company Name        RetailCo  ...       SkyHigh                  SecureNet
# ...

# %%
cd=cd.T
cd
# Out:
#                               1               2              3   \
# Company Name            TechCorp      HealthPlus       EduWorld
# Employee Name        Alice Smith     Bob Johnson  Charlie Brown
# Position       Software Engineer  Data Scientist        Teacher
#
#                               4                    5             6   \
# Company Name            FinTrust              AutoMax       BioLife
# Employee Name         Dana White            Eve Davis  Frank Wilson
# Position       Financial Analyst  Mechanical Engineer     Biologist
#
#                           7           8                        9   \
# Company Name    WebSolutions    MediCare              GreenEnergy
# Employee Name      Grace Lee  Henry King                Ivy Lewis
# Position       Web Developer       Nurse  Environmental Scientist
#
#                           10  ...            41                         42  \
# Company Name        RetailCo  ...       SkyHigh                  SecureNet
# ...

# %%
cd.to_csv('comapny data.csv',index=False)

# %%
com_dat=pd.read_csv('company data.csv')
com_dat
com_dat.drop(2,axis=0,inplace=True)
com_dat
com_dat.drop((i for i in[42,34,6,7]),axis=0,implace=Treue)
com_dat.reset_index(drop=True,inplace=True)
com_datcom_dat.to csv('company data.csv'index=False)
com_dat.to_excel('comapny data.xls',index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 com_dat=pd.read_csv('company data.csv')
#       2 com_dat
#
# File C:\Program Files\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...
