# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
sm=pd.read_csv('marks_1.csv')
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
# [559 rows x 7 columns]

# %%
sm['Total']=sm[['English','Hindi','Science','SST']].sum(axis=1)
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total
# 0      208
# 1      284
# 2      129
# 3      251
# 4      141
# ..     ...
# 554    281
# 555     68
# 556     84
# 557    326
# 558    339
#
# [559 rows x 8 columns]

# %%
sm['Percentage']=(sm['Total']/5)
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total  Percentage Grade
# 0      208        41.6     D
# 1      284        56.8     C
# 2      129        25.8     F
# 3      251        50.2     C
# 4      141        28.2     F
# ..     ...         ...   ...
# 554    281        56.2     C
# 555     68        13.6     F
# 556     84        16.8     F
# 557    326        65.2     B
# 558    339        67.8     B
#
# [559 rows x 10 columns]

# %%
A=100-80
B=80-60
C=60-50
D=50-40
E=40-30
F=0-30

# %%
def clac_grade(p):
    if p<=100 and p>=80:
        return 'A'
    elif p<80 and p>=60:
        return 'B'
    elif p<60 and p>=50:
        return 'C'
    elif p<50 and p>=40:
        return 'D'
    elif p<40 and p>=30:
        return 'E'
    elif p<30 and p>=0:
        return 'F'
    else:
       return 'X'

sm['Grade']=sm['Percentage'].apply(clac_grade)
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total  Percentage Grade
# 0      208        41.6     D
# 1      284        56.8     C
# 2      129        25.8     F
# 3      251        50.2     C
# 4      141        28.2     F
# ..     ...         ...   ...
# 554    281        56.2     C
# 555     68        13.6     F
# 556     84        16.8     F
# 557    326        65.2     B
# 558    339        67.8     B
#
# [559 rows x 10 columns]

# %%
temp=sm.head()
temp
# Out:
#    Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0        1            A HariCharan        80     66     98       21   41
# 1        2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2        3           A Pavan Kumar        41     46     26        7   35
# 3        4            Aaditya Nanda       64     99      6       16   72
# 4        5        Aakanksha Kaushal       38     20     40       33   50
#
#    Total  Percentage Grade
# 0    208        41.6     D
# 1    284        56.8     C
# 2    129        25.8     F
# 3    251        50.2     C
# 4    141        28.2     F

# %%
    # sub= ['English','Hindi','Science','SST']

    # plt.figure(figsize=(10,6))
    # plt.plot(temp['Name'],temp[sub,marker='o',label=sub)
    # plt.title("Marks in different Subjects")
    # plt.xlabel('Name')
    # plt.ylabel('Marks')
    # plt.legend()
    # plt.grid(True)
    # plt.show()

# %%
    sub= ['English','Hindi','Science','SST']
    
    plt.figure(figsize=(10,5))
    plt.plot(temp['Name'],temp[sub],marker='o',label=sub)
    plt.title("Marks in different Subjects")
    plt.xlabel('Name')
    plt.ylabel('Marks')
    plt.legend()
    plt.grid(True)
    plt.show()
